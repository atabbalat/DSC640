# %% [markdown]
# ### Week 3 & 4
# ### DSC 640
# ### Abed Tabbalat
# ### Python

# %%
# Library Imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
# Settings
pd.set_option("display.max_rows", 10, "display.max_columns", 10)
plt.style.use('seaborn')
sns.set_style('whitegrid')

# %%
# Data import
df = pd.read_excel('world-population.xlsm')
df
# Out:
#     Year  Population
# 0   1960  3028654024
# 1   1961  3068356747
# 2   1962  3121963107
# 3   1963  3187471383
# 4   1964  3253112403
# ..   ...         ...
# 45  2005  6462054420
# 46  2006  6538196688
# 47  2007  6614396907
# 48  2008  6692030277
# 49  2009  6775235741
#
# [50 rows x 2 columns]

# %%
df['Population1000'] = df['Population'] / 1000000

x = df['Year']
y = df['Population1000']

# %% [markdown]
# ### Applying Charts

# %% [markdown]
# #### Line Chart

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot
sns.lineplot(x=x, y=y, color='orange')

# Format
plt.xlabel('Year', fontsize=15)
plt.xticks(fontsize=13)
plt.ylabel('World Population in Millions', fontsize=15)
plt.yticks(fontsize=13)
plt.title('Python - Line Chart\nWorld Population in Millions', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Python - Line Chart\nWorld Population in Millions')

# %% [markdown]
# #### Step Chart

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# Plot
plt.step(x, y, color='orange')

# Format
plt.xlabel('Year', fontsize=15)
plt.xticks(fontsize=13)
plt.ylabel('World Population', fontsize=15)
plt.yticks(fontsize=13)
plt.title('Python - Step Chart\nWorld Population', fontsize=25)
# Out:
# Text(0.5, 1.0, 'Python - Step Chart\nWorld Population')
